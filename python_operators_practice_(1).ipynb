# %% [markdown]
# # Python Operators Practice Notebook
#
# Each question is followed by its solution in the next code cell.
# Difficulty level: Easy to Medium.

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# Q1. Add two numbers a = 10 and b = 5.

# %%
# write your answer here
a = 10
b = 5

print(f"the sum of two num. are {a+b}")
# Out:
# the sum of two num. are 15

# %% [markdown]
# Q2. Find the remainder when 17 is divided by 4.

# %%
# write your answer here
a = 17
b = 4

print(f"the remainder of two num. are {a%b}")
# Out:
# the remainder of two num. are 1

# %% [markdown]
# Q3. Calculate 3 raised to the power 4.

# %%
# write your answer here
a = 3
b = 4

print(f"the remainder of two num. are {a**b}")
# Out:
# the remainder of two num. are 81

# %% [markdown]
# ## Assignment Operators

# %% [markdown]
# Q4. Assign 10 to x and add 5 to it using assignment operator.

# %%
# write your answer here
x = 10
x +=5

print(x)
# Out:
# 15

# %% [markdown]
# Q5. Assign 20 to y and multiply it by 2 using assignment operator.

# %%
# write your answer here
y = 20
y *=2

print(y)
# Out:
# 40

# %% [markdown]
# Q6. Assign 15 to z and subtract 7 using assignment operator.

# %%
# write your answer here
z = 15
z -=7

print(z)
# Out:
# 8

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# Q7. Check if 10 is greater than 5.

# %%
# write your answer here
a = 10
b = 5

print(f"compairing the value:{a>b}")
# Out:
# compairing the value:True

# %% [markdown]
# Q8. Check if 7 is equal to 9.

# %%
# write your answer here
a = 7
b = 9

print(f"compairing the value:{a==b}")
# Out:
# compairing the value:False

# %% [markdown]
# Q9. Check if 8 is not equal to 3.

# %%
# write your answer here
a =8
b = 3

print(f"compairing the value {a!=b}")
# Out:
# compairing the value True

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# Q10. Check if 5 > 2 and 10 > 3.

# %%
# write your answer here
a = 5
b = 2
c = 10
d = 3

print(f"compairing the value {a>b and c>d}")
# Out:
# compairing the value True

# %% [markdown]
# Q11. Check if 5 > 10 or 3 < 7.

# %%
# write your answer here
a = 5
b = 10
c = 3
d = 7

print(f"compare the value {(5>10) or (3<7)}")
# Out:
# compare the value True

# %% [markdown]
# Q12. Use not operator on condition 10 > 5.

# %%
# write your answer here
a = 10
b = 5

print(f"compare the value {not(a>b)}")
# Out:
# compare the value False

# %% [markdown]
# ## Identity Operators

# %% [markdown]
# Q16. Check if a and b refer to the same object.
# Let a = 10, b = 10.

# %%
# write your answer here
a = 10
b = 10

print(f" the object is { a==b}")
# Out:
#  the object is True

# %% [markdown]
# Q18. Compare identity of two variables c and d where c = d = 5.

# %%
# write your answer here
c = 5
c =  d

print(f"compare the value {c==d}")
# Out:
# compare the value True

# %% [markdown]
# ## Membership Operators

# %% [markdown]
# Q19. Check if 3 is present in the list [1,2,3,4].

# %%
# write your answer here
a = {1,2,3,4}

print(f"check the value:{3 in a}")
# Out:
# check the value:True

# %% [markdown]
# Q20. Check if 'a' is not present in the string 'python'.

# %%
# write your answer here
string = "python"

print(f" check the string: {'a' in string}")
# Out:
#  check the string: False

# %% [markdown]
# Q21. Check if 10 is in the tuple (5, 10, 15).

# %%
# write your answer here
tuple = (5,10,15)

print(f"check the tuple:{ 10 in tuple } ")
# Out:
# check the tuple:True
